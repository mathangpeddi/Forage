# %%
import pandas as pd
import numpy as np
import datetime
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
import warnings
import math as ma
warnings.filterwarnings("ignore")

# %%
import os
os.chdir('/home/user/KPMG/KPMG2')

# %%
df=pd.read_csv('Customerdemographic.csv')

# %%
df.head()
# Out:
#   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                                720
# 1                                               1092
# 2                                               3410
# 3                                               2413
# 4                                                658
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0     Darrel      Canet       Male         67  1931-10-23
# 1     Katlin    Creddon     Female         56  1935-08-22
# 2    Merrili    Brittin     Female         93  1940-09-22
# 3      Abbey     Murrow       Male         27  1943-08-11
# 4       Donn    Bonnell       Male         38  1944-01-24
#
#                  Unnamed: 6     Unnamed: 7         Unnamed: 8 Unnamed: 9  \
# 0        Recruiting Manager         Retail  Affluent Customer          N
# 1        VP Quality Control         Retail      Mass Customer          N
# 2                       NaN       Property      Mass Customer          N
# 3  Environmental Specialist  Manufacturing     High Net Worth          N
# 4            Tax Accountant  Manufacturing  Affluent Customer          N
#
#           Unnamed: 10 Unnamed: 11 Unnamed: 12
# 0  1;DROP TABLE users          No           6
# 1  ì¬íê³¼íì ì´íì°êµ¬ì          No           5
# 2                   á          No          16
# 3                  á          Yes          17
# 4  ì¬íê³¼íì ì´íì°êµ¬ì         Yes           8

# %%
df.rename(columns={"Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only. ":"customer_id"}, inplace = True)
df.rename(columns={"Unnamed: 1":"fname",
                   "Unnamed: 2":"lname",
                   "Unnamed: 3":"gender",
                   "Unnamed: 4":"3y_bike_purchases",
                   "Unnamed: 5":"DOB",
                   "Unnamed: 6":"JT"}, inplace = True)
df.rename(columns={"Unnamed: 7":"Category",
                   "Unnamed: 8":"wealth_segement",
                   "Unnamed: 9":"D_Indicator",
                   "Unnamed: 10":"default",
                   "Unnamed: 11":"owns_car",
                   "Unnamed: 12":"tencure"}, inplace = True)
df=df.iloc[1:]
df
# Out:
#      customer_id    fname      lname  gender 3y_bike_purchases         DOB  \
# 1           1092   Katlin    Creddon  Female                56  1935-08-22
# 2           3410  Merrili    Brittin  Female                93  1940-09-22
# 3           2413    Abbey     Murrow    Male                27  1943-08-11
# 4            658     Donn    Bonnell    Male                38  1944-01-24
# 5           1243  Robbert     Blakey    Male                73  1953-08-09
# ...          ...      ...        ...     ...               ...         ...
# 3996        3779    Ulick     Daspar       U                68         NaN
# 3997        3883    Nissa     Conrad       U                35         NaN
# 3998        3931    Kylie      Epine       U                19         NaN
# 3999        3935   Teodor  Alfonsini       U                72         NaN
# 4000        3998   Sarene    Woolley       U                60         NaN
#
#                             JT       Category    wealth_segement D_Indicator  \
# 1           VP Quality Control         Retail      Mass Customer           N
# 2                          NaN       Property      Mass Customer           N
# 3     Environmental Specialist  Manufacturing     High Net Worth           N
# 4               Tax Accountant  Manufacturing  Affluent Customer           N
# 5        Research Assistant II         Retail      Mass Customer           N
# ...                        ...            ...                ...         ...
# 3996                       NaN             IT  Affluent Customer           N
# 3997           Legal Assistant             IT      Mass Customer           N
# 3998                       NaN             IT     High Net Worth           N
# 3999                       NaN             IT     High Net Worth           N
# 4000         Assistant Manager             IT     High Net Worth           N
#
#                  default owns_car tencure
# 1     ì¬íê³¼íì ì´íì°êµ¬ì       No       5
# 2                      á       No      16
# 3                     á       Yes      17
# 4     ì¬íê³¼íì ì´íì°êµ¬ì      Yes       8
# 5                     "'       No       8
# ...                  ...      ...     ...
# 3996                 NaN       No     NaN
# 3997                 NaN       No     NaN
# 3998                 NaN      Yes     NaN
# 3999                 NaN      Yes     NaN
# 4000                 NaN       No     NaN
#
# [4000 rows x 13 columns]

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male', 'F', 'Femal', 'M', 'U', 'gender'], dtype=object)

# %%
gender = [0,0,0] #first is Female, second if Male, third is Unknown
for each in df['gender']:
    if each[0] == "F":
        gender[0] += 1
    elif each[0] == "M":
        gender[1] += 1
    else:
        gender[2] += 1

print(gender)
# Out:
# [2039, 1872, 89]

# %%
df['gender'].value_counts()
# Out:
# Female    2037
# Male      1871
# U           88
# Femal        1
# F            1
# gender       1
# M            1
# Name: gender, dtype: int64

# %%
df['wealth_segement'].unique()
# Out:
# array(['Mass Customer', 'High Net Worth', 'Affluent Customer',
#        'wealth_segment'], dtype=object)

# %%
df['wealth_segement'].value_counts()
# Out:
# Mass Customer        2000
# High Net Worth       1021
# Affluent Customer     978
# wealth_segment          1
# Name: wealth_segement, dtype: int64

# %%
df.dtypes
# Out:
# customer_id          object
# fname                object
# lname                object
# gender               object
# 3y_bike_purchases    object
# DOB                  object
# JT                   object
# Category             object
# wealth_segement      object
# D_Indicator          object
# default              object
# owns_car             object
# tencure              object
# dtype: object

# %%
df['3y_bike_purchases'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-d76be240756e> in <module>
# ----> 1 df['3y_bike_purchases'].astype(int)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     872         # work around NumPy brokenness, #1987
#     873         if np.issubdtype(dtype.type, np.integer):
# --> 874             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     875
#     876         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: 'past_3_years_bike_related_purchases'
